# %% [markdown]
# <a href="https://colab.research.google.com/github/brittabeta/Bellabeat-Case-Study-SQL-Excel-Tableau/blob/main/Cyclistic%20Bikeshare%20Case%20Study%20in%20R.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Cyclistic Bikeshare Case Study**
#
# ## **By: Britta Smith**
#
# Tools: R, Tableau, Excel
#
# In Association with: Google Data Analytics Certification

# %%
# load rmagic to use R in Colab notebook
# %load_ext rpy2.ipython

# %%
# use %%R to execute cell magic
